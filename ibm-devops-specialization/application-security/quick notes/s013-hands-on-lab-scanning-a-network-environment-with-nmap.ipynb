# %% [markdown]
# # Objectives

# %% [markdown]
# After completing this lab, you will be able to:
# 1. Use ZenMap, the GUI utility, provided by NMap
# 2. Perform a network scan based on the IP Address or domain name
# 3. Review different scan options in the ZenMap utility

# %% [markdown]
# # Important Notices about This Lab

# %% [markdown]
# ## About Lab Sessions

# %% [markdown]
# Lab sessions are not persisted. This means that every time you connect to this lab, a new environment is created for you. Any data or files you saved in a previous session are no longer available. To avoid losing your data, plan to complete these tasks in a single session.

# %% [markdown]
# ## About the Lab Instructions and Solutions

# %% [markdown]
# In case you try to use your physical keyboard in the lab environment, it might not produce any visible results. To avoid this issue, please use the On-Screen Keyboard (you can find it by searching for **"On-Screen Keyboard"** in the search bar at the bottom of your screen). If the search functionality doesn't work, you can also click on the Windows icon, scroll down to find Windows Ease of Access, click on it, and then select On-Screen Keyboard.
#
# Microsoft Windows operating system features can vary based on the Windows edition. If completing these exercises on your machine, your navigation and solutions may differ from what's presented in this lab.

# %% [markdown]
# # Task 1 - Install NMap

# %% [markdown]
# 1. Open any browser of your choice in your virtual environment.
#
#     ![image.png](attachment:8c410068-d1cf-4659-b728-acbcc8724384.png)
#
# 2. Type **`https://nmap.org/download`** in the search bar and press enter.
#
#     ![image.png](attachment:bc81db25-07f4-4fad-946f-3e12aebf2b57.png)
#
# 3. Click the OS that you need the software for.
#     * This lab's instructions are based on Windows OS.
#     * The steps might slightly vary for other operating systems.
#
#     ![image.png](attachment:68c238d7-a808-411d-8f86-28531c8b9684.png)
#
# 4. Click the installation executable for windows.
#
#     ![image.png](attachment:4ad4a77b-6022-4916-a358-e4dc39e92ac1.png)
#
# 5. Once the download completes, click the **`.exe`** file to begin the installation.
#
#     ![image.png](attachment:50bf5fa5-502b-414a-b623-f262219a4783.png)
#
#     > *This will download NMap and Zenmap a GUI utility for **NMap** which is a great tool to use when you begin learning **NMap**.*
#
# 6. Complete the process of installation by following the instructions.
#
#     ![image.png](attachment:83be2e0d-3127-4348-87bb-c4f685cd6baf.png)
#
# **Note:**
# * Click **"I agree"** to proceed with the installation.
# * Make sure to install all required dependencies and then click **"Finish"** to complete the setup.

# %% [markdown]
# # Task 2 NMap with Zenmap

# %% [markdown]
# 1. Click to open the Zenmap app on your desktop.
#
#     ![image.png](attachment:dbb4c60e-ed9c-4a94-a7b2-a10152e0ea45.png)
#
# 2. This opens the Zenmap application.
#
#     ![image.png](attachment:76f1c80d-3d57-41e5-9a04-4a347762ac3a.png)
#
# 3. In the **Target** field, enter **scanme.nmap.org**.
#     * This routes to your local system.
#
#     ![image.png](attachment:1fef20f3-ae9a-4199-b406-e7a77d23f6c3.png)
#
# 4. Choose **Quick Scan** from the scan options.
#
#     ![image.png](attachment:6645d594-58c1-48e3-8187-bf4b4891212c.png)
#
# 5. Click **Scan** to begin the scan process.
#
#     ![image.png](attachment:80126ed9-21d7-432f-a063-295f4300796d.png)
#
# 6. You can see the output of the scan in the first **Nmap Output** scan results tab.
#
#     ![image.png](attachment:c3e24207-90ef-4b63-8d87-92be6c9701f6.png)
#
# 7. Now from the list of scan options choose **Intense scan**.
#     * This is a more intense scan and gives detailed results.
#     * In realtime this will take a few minutes.
#     * Click **Scan** to begin intense scanning.
#
#     ![image.png](attachment:370778fb-6181-46a1-921b-ad5d43c15f7e.png)
#
# 8. Once the scan finishes, you will see the detailed output along with how long the scanning took in the NMap output tab.
#
#     ![image.png](attachment:774db3e4-4fc1-4500-942c-27efd377c087.png)
#
# 9. Click the **Ports/Hosts** tab to see state the ports in the target system.
#     * The **green** indicates open ports and **red** indicates closed ports.
#
#     ![image.png](attachment:67870a67-d941-4faf-b1cc-8fbba36c2e06.png)
#
# 10. Click the **Topology** tab to view the visualization of the hosts on this network.
#     * If a host has less than 3 ports, it will be green.
#     * If it has 3 to 5 ports it will be yellow.
#     * If it has more 6, it will be red.
#     * This will be evident when you test on real networks.
#
#     ![image.png](attachment:b651c969-ef7a-4938-91b5-d5278488d2ac.png)
#
# 11. Click the **Host Details** tab to get the details about the host you are scanning.
#     * The details will include the Host status, Address, Hostname, Operating system, and so on.
#
#     ![image.png](attachment:9085ff58-96bf-4035-9b8b-3ea6d98036ef.png)
#
# 12. Change the target to **127.0.0.1** which is the IP address for your localhost and click **Scan**.
#
#     ![image.png](attachment:c75351b6-48f8-46cd-b7b5-55f7837c6a06.png)
#
# 13. See the Nmap output of **127.0.0.1**.
#
#     ![image.png](attachment:77f8fb44-3e22-4f44-9ed2-d682e6cd82b0.png)
#
# 14. Change the target to **`cloud.ibm.com`** and click **Scan**.
#
#     ![image.png](attachment:f7de8b5b-456b-4450-84d9-f897aec0135a.png)
#
# 15. See the **Nmap** output of **`cloud.ibm.com`**.
#
#     ![image.png](attachment:f46fff40-a360-4749-92cf-1c4b7de493f3.png)
#
# Congratulations! Now you are familiar with using NMap to scan networks.
