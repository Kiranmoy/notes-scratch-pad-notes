# %% [markdown]
# # Learning Objectives

# %% [markdown]
# After completing this exercise, you will be able to:
# * Perform a scan of your code repository
# * Analyze the code repository report

# %% [markdown]
# # Pre-requisites

# %% [markdown]
# * You must have a GitHub account. If you don't have a GitHub account go to [this link](https://github.com/signup?ref_cta=Sign+up&ref_loc=header+logged+out&ref_page=%2F&source=header-home), follow the instructions and sign-up.
#
# * You should have some public and private repositories in your GitHub. If you don't have any, then let's create one. For example, if you want to create a copy of another public repository, **[https://github.com/bitnami/containers](https://github.com/bitnami/containers)**, go to the repository. Click **Fork** to fork the repository into your account. This will make a copy of the repository for you.
#
# ![image.png](attachment:ca154550-2a7d-45e0-b880-22a84c1aa021.png)

# %% [markdown]
# # Adding a project to SNYK

# %% [markdown]
# **SNYK software has many capabilities. But we will focus on the code repository vulnerability check which is offered as a free service.**
#
# 1. **Go to [https://app.snyk.io/login](https://app.snyk.io/login) and click `login` with GitHub.**
#
# ![image.png](attachment:a6e2c459-db9d-4d73-9ced-07b6cbaa3c05.png)
#
# 2. **If you are already logged into GitHub in your browser, go to next step. Otherwise, `login` with your Github credentials.**
#
# ![image.png](attachment:f2dec8d1-e5a8-43fd-b736-d12800133b61.png)
# ![image.png](attachment:b2c64787-216f-4fcb-ac51-ab718b8b3dc1.png)
# ![image.png](attachment:3d79b72f-0c2f-4c6b-bc82-5b72e0f6f585.png)
#
# 3. **Provide permission and authorize snyk to use your GitHub credentials to login.**
#
# ![image.png](attachment:6c8651f0-a3fc-4c22-a28b-7cc66c8fca03.png)
# ![image.png](attachment:3410b6ab-db3a-4469-8dcf-a8696fc2bec2.png)
# ![image.png](attachment:cd60877e-bd02-4e8e-b17a-ae0cd498db1c.png)
#
# 4. **The first time you login, it asks if you want to subscribe for information on product releases and feature updates. Click `No, not right now`**.
#
# ![image.png](attachment:7d1e5cf2-5779-4446-9387-398f43286ca0.png)
# ![image.png](attachment:85b1d8c6-6fed-4644-8d2d-0604eeada423.png)
#
# 5. **Choose the location of the code you want to test. For this exercise, choose Github. You are free to choose BitBucket if you have an account already.**
#
# ![image.png](attachment:ccaf9cc0-450d-4bf4-8fce-437dd22b2678.png)
# ![image.png](attachment:6aa4f530-14dd-4279-9896-6b5fbe583ad3.png)
#
# 6. **You are presented with options to choose between using both public and private repositories (or repos) or just the public repos. Choose `Public repos only`.**
#
# ![image.png](attachment:92d0b697-d9c5-4a2d-8973-0d08421c0568.png)
# ![image.png](attachment:35c0ed74-5acf-4c37-ad63-ef891b1e37bb.png)
#
# 7. **Check and select all the types of scans you would like snyk to do and click `Authenticate Github`.**
#
# ![image.png](attachment:2d073898-e452-4614-be79-99dd1cb8fe83.png)
# ![image.png](attachment:2f46ddbd-c95a-4aee-ba4c-54b5ee8f7e4e.png)
#
# 8. **Github requires you to explicitly allow snyk to use your public repos. Click `Authorize snyk` to do so.**
#
# ![image.png](attachment:cdf73871-4f26-4b76-8f38-49d0f8c15f39.png)
# ![image.png](attachment:decda928-07a1-4b7f-99fe-5ebfee54346e.png)
# ![image.png](attachment:35cc5929-7f54-47a8-b66b-c85e4c18373b.png)
#
# 9. It takes you to the `Dashboard`, where you can click `Add Projects`. You have options to choose from.
# * Github
# * CLI
# * Monitor public Github repos
# * Other sources (BitBucket, Cloud, etc.,)
#
# ![image.png](attachment:b9452cda-b5f3-4447-b299-939a47fd59e2.png)
# ![image.png](attachment:5d52af68-3fbb-4843-965f-efcc04d0a6d3.png)
#
# 10. **Click `Github` to see all your public repos listed. You can scan one of your public repos.**
#
# 11. **You can choose your repos and Add the selected repos to scan.**
#
# ![image.png](attachment:f1f644ed-4ebe-44c7-885a-384c33d1a898.png)
#
# > *Depending on the size of your repo, scan might take time.*
#
# 12. **Click `Add Project` again and choose, `Monitor public Github repos` option.**
#
# ![image.png](attachment:fd7fd35c-64c5-4359-96e0-483749f43b9c.png)
#
# 13. **Type the name of a public url. For example, the image below shows [https://github.com/bitnami/containers](https://github.com/bitnami/containers). Click `Add repo` and then click `Import 1 repository`.**
#
# ![image.png](attachment:62bf94e4-6493-46e1-ad15-b0cd73439308.png)
#
# 14. **Once the repo is imported, the scanning begin for vulnerabilities. This take a few seconds, after which a report is generated showing how many projects in the repository were scanned and how many `Critical`, High` priority, `Medium` priority and `Low` priority vulnerabilities were found in these.**
#
# ![image.png](attachment:11c4529e-adf6-43ec-8367-22e5cf655941.png)

# %% [markdown]
# **Congratulations! You just learned how to scan code with Snyk.**
#
# You may try to run this code scan on your own repos or other public GitHub repositiries for practice.
