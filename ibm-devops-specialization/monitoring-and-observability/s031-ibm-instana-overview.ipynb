# %% [markdown]
# # What you'll learn

# %% [markdown]
# After watching this video, you'll be able to **explain Instana and its uses**.

# %% [markdown]
# # What is IBM Instana observability?

# %% [markdown]
# ![image.png](attachment:6872f764-af97-493e-94fc-4420cad93eeb.png)
#
# Let's begin by understanding what IBM Instana Observability is and its uses.
# * IBM Instana Observability, popularly known as Instana, is a fully automated application performance management, or APM solution.
# * Designed to overcome the challenges of managing microservices and cloud-native applications.
# * Instana automatically makes your applications and services visible, provides context to the observed information, and enables you to take intelligent actions based on that information.

# %% [markdown]
# # Use cases of Instana

# %% [markdown]
# ![image.png](attachment:7fd79222-f08d-494c-bd4a-3d9491900153.png)
#
# * Instana monitors and analyzes your applications, services, infrastructure, web, browsers, mobile applications, and more for over 200 domain-specific technologies.
# * Instana automates dependency mapping across the full stack for flexible application perspectives and provides powerful, easy to use data analytics.
# * Instana informs you whenever your customers are impacted by performance or stability issues in your applications within a few seconds of impact.
#
# ![image.png](attachment:03c28234-ea37-416c-8393-c6cdce93389b.png)
#
# * In addition, Instana automates root-cause analysis by using event correlation, performance thresholds, errors, changes, and analysis of service level agreement or SLA violations.
# * Instana also provides real-time observability metrics with data at a granularity of 1 second and traces every end-to-end, mobile, web and application transaction.

# %% [markdown]
# # Alerts in Instana

# %% [markdown]
# ![image.png](attachment:d859adfe-ecb3-4bfd-bf7c-cb788f57bf77.png)
#
# * Automated smart alerts provide threshold-based alerts based on out of the box blueprints.
# * Instana monitors over 200 technologies, such as technologies related to cloud and infrastructure, tracing, alerting, notifications, CI/CD logging, and metrics.

# %% [markdown]
# # Infrastructure monitoring with Instana

# %% [markdown]
# ![image.png](attachment:034cfde3-40ac-45a0-8aad-65c58984de1c.png)
#
# * Infrastructure is the underlying layer to provide the relevant resources and services for applications, especially in modern architectures.
# * The infrastructure constantly changes and leverages concepts like clustering and autoscaling to ensure reliability, scaling, and flexibility.
# * Instana ensures that at any time the infrastructure is monitored and represented as it is.
# * All issues and changes detected on the infrastructure are constantly related to any occurring issues and incidents on the application and end user level.
# * Giving the users a comprehensive understanding of all parts that deliver the application.

# %% [markdown]
# # Summary

# %% [markdown]
# ![image.png](attachment:8b706dd9-8f08-4500-a058-25f6c5f9c4f7.png)
#
# In this video, you learned that:
# * Instana is a fully automated application performance management solution designed to overcome the challenges of managing microservice and cloud-native applications.
# * You also explored Instana's features and uses and various components of Instana's dashboards.
# * Finally, you learn the process to install Instana agents to monitor your technology stacks as you need.
# * The Analyze Infrastructure feature and its benefits.
